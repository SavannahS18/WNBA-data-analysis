# %%
s = "Data Science"
print(s[0])
print(s[-1])
print(s[5:])
# Out:
# D
# e
# Science

# %%
s = "Data Science"
print(s.upper())
print(s.lower())
print(s.replace("Science", "Python"))
# Out:
# DATA SCIENCE
# data science
# Data Python

# %%
s = "Data Science"
print(s.find("S"))
# Out:
# 5

# %%
fruits = "apple,banana,cherry"
print(fruits.split(","))
# Out:
# ['apple', 'banana', 'cherry']
